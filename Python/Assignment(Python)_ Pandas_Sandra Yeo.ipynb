# %%
#1) Import the pandas library

import pandas as pd

#Import absenteesm dataset(provided) and assign it to “df”

df = pd.read_csv("/Users/hwing/Downloads/Absenteeism.csv")

#Find out the “type” of the dataset.

type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
#2) Find the info of the data set.

df
# Out:
#      ID  Reason for Absence        Date  Transportation Expense  \
# 0    11                  26  07/07/2015                     289
# 1    36                   0  14/07/2015                     118
# 2     3                  23  15/07/2015                     179
# 3     7                   7  16/07/2015                     279
# 4    11                  23  23/07/2015                     289
# ..   ..                 ...         ...                     ...
# 695  17                  10  23/05/2018                     179
# 696  28                   6  23/05/2018                     225
# 697  18                  10  24/05/2018                     330
# 698  25                  23  24/05/2018                     235
# 699  15                  28  31/05/2018                     291
#
#      Distance to Work  Age  Daily Work Load Average  Body Mass Index  \
# 0                  36   33                  239.554               30
# ...

# %%
#3) Drop the first column “ID”, and save it back to “df”.

#df = df.drop(columns=['ID'])

df
# Out:
#      Reason for Absence        Date  Transportation Expense  Distance to Work  \
# 0                    26  07/07/2015                     289                36
# 1                     0  14/07/2015                     118                13
# 2                    23  15/07/2015                     179                51
# 3                     7  16/07/2015                     279                 5
# 4                    23  23/07/2015                     289                36
# ..                  ...         ...                     ...               ...
# 695                  10  23/05/2018                     179                22
# 696                   6  23/05/2018                     225                26
# 697                  10  24/05/2018                     330                16
# 698                  23  24/05/2018                     235                16
# 699                  28  31/05/2018                     291                31
#
# ...

# %%
#4) Drop the age column. And save it back to “df”

#df = df.drop(columns=['Age'])

df
# Out:
#      Reason for Absence        Date  Transportation Expense  Distance to Work  \
# 0                    26  07/07/2015                     289                36
# 1                     0  14/07/2015                     118                13
# 2                    23  15/07/2015                     179                51
# 3                     7  16/07/2015                     279                 5
# 4                    23  23/07/2015                     289                36
# ..                  ...         ...                     ...               ...
# 695                  10  23/05/2018                     179                22
# 696                   6  23/05/2018                     225                26
# 697                  10  24/05/2018                     330                16
# 698                  23  24/05/2018                     235                16
# 699                  28  31/05/2018                     291                31
#
# ...

# %%
#5) What are the smallest and largest values of the column “reason for absence”.

column = df["Reason for Absence"]
maxvalue = column.max()
minvalue = column.min()
print (maxvalue)
print (minvalue)
# Out:
# 28
# 0

# %%
#6) What is the length of the  column “reason of absence”?

length = len(column)
print (length)
# Out:
# 700

# %%
#7) Find the data types of the remaining columns.

df.info(null_counts=False)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 700 entries, 0 to 699
# Data columns (total 10 columns):
#  #   Column                     Dtype
# ---  ------                     -----
#  0   Reason for Absence         int64
#  1   Date                       object
#  2   Transportation Expense     int64
#  3   Distance to Work           int64
#  4   Daily Work Load Average    float64
#  5   Body Mass Index            int64
#  6   Education                  int64
#  7   Children                   int64
#  8   Pets                       int64
#  9   Absenteeism Time in Hours  int64
# dtypes: float64(1), int64(8), object(1)
# memory usage: 54.8+ KB

# %%
#8) Create a line graph to show the relationship between 
#the column “reason for absence” and “Absenteeism Time in Hours”.

import matplotlib.pyplot as plt
# %matplotlib inline

ax = plt.gca()

df.plot(kind = 'line', x = "Reason for Absence", y = "Absenteeism Time in Hours", color = "blue", ax=ax)
plt.show()

# %%
#9) Create a suitable graph to derive useful insights from the columns distance in hours and absenteeism hours

df.plot(kind = 'scatter', x = "Distance to Work", y = "Absenteeism Time in Hours", color = "red")
plt.show()
